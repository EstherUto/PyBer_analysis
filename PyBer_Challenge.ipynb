# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command

# %matplotlib inline

# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)

city_data_to_load = "resources/city_data.csv"
ride_data_to_load = "resources/ride_data.csv"

# Read the City and Ride Data

city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset

pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview

pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Summary DataFrame

# %%
#  1. Get the total rides for each city type

rides = pyber_data_df.groupby(["type"]).count()["ride_id"]

urban_rides = rides["Urban"]
suburban_rides = rides["Suburban"]
rural_rides = rides["Rural"]

total_rides = rides.sum()

rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type

drivers = city_data_df.groupby(["type"]).sum()["driver_count"]

urban_drivers = drivers["Urban"]
suburban_drivers = drivers["Suburban"]
rural_drivers = drivers["Rural"]

total_drivers = drivers.sum()

drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type

fares = pyber_data_df.groupby(["type"]).sum()["fare"]

urban_fares = fares["Urban"]
suburban_fares = fares["Suburban"]
rural_fares = fares["Rural"]

total_fares = fares.sum()

fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 

avg_fares = fares / rides

urban_avg_fares = avg_fares["Urban"]
suburban_avg_fares = avg_fares["Suburban"]
rural_avg_fares = avg_fares["Rural"]

avg_fares
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 

avg_fare_per_driver = fares / drivers

urban_avg_fare_per_driver = avg_fare_per_driver["Urban"]
suburban_avg_fare_per_driver = avg_fare_per_driver["Suburban"]
rural_avg_fare_per_driver = avg_fare_per_driver["Rural"]

avg_fare_per_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

pyber_summary_df = pd.DataFrame({
    "Total Rides": rides,
    "Total Drivers": drivers,
    "Total Fares": fares,
    "Average Fare per Ride": avg_fares,
    "Average Fare per Driver": avg_fare_per_driver
})
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.

pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Multiple line plot showing the total weekly fares for each type of city.

# %%
# 1. Read the merged DataFrame

pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#  Change the 'date' column to a datetime object.

pyber_data_df['date']= pd.to_datetime(pyber_data_df['date'])

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

pyber_data_new = pyber_data_df.groupby(["type", "date"]).sum("fare")
pyber_data_new.head()
# Out:
#                             fare        ride_id  driver_count
# type  date
# Rural 2019-01-01 09:45:36  43.69  2424875833354             1
#       2019-01-02 11:18:32  52.12  3454018971635             1
#       2019-01-03 19:51:01  19.90  5559509612597             8
#       2019-01-04 03:31:26  24.88  4195619112933             8
#       2019-01-06 07:38:40  47.33  3849747342021             4

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.

pyber_data_new = pyber_data_new.reset_index()
pyber_data_new
# Out:
#        type                date   fare        ride_id  driver_count
# 0     Rural 2019-01-01 09:45:36  43.69  2424875833354             1
# 1     Rural 2019-01-02 11:18:32  52.12  3454018971635             1
# 2     Rural 2019-01-03 19:51:01  19.90  5559509612597             8
# 3     Rural 2019-01-04 03:31:26  24.88  4195619112933             8
# 4     Rural 2019-01-06 07:38:40  47.33  3849747342021             4
# ...     ...                 ...    ...            ...           ...
# 2370  Urban 2019-05-08 04:20:00  21.99   117997692054            52
# 2371  Urban 2019-05-08 04:39:49  18.45  1811574736337            11
# 2372  Urban 2019-05-08 07:29:01  18.55  5682021476085            33
# 2373  Urban 2019-05-08 11:38:35  19.77  7837163332630             4
# 2374  Urban 2019-05-08 13:10:18  18.04  5616262558026            58
#
# [2375 rows x 5 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 

pyber_data_pivot = pyber_data_new.pivot(index = "date", columns = "type", values = "fare")
pyber_data_pivot
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

trips_2019 = pyber_data_pivot.loc['2019-01-01':'2019-04-29']
trips_2019
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-29 20:54:19    NaN       NaN  28.41
# 2019-04-29 21:20:41    NaN       NaN  13.59
# 2019-04-29 22:08:22    NaN     25.75    NaN
# 2019-04-29 23:05:04    NaN       NaN  14.59
# 2019-04-29 23:10:18    NaN     29.39    NaN
#
# [2218 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.

trips_2019.index = pd.to_datetime(trips_2019.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
trips_2019.info
# Out:
# <bound method DataFrame.info of type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-29 20:54:19    NaN       NaN  28.41
# 2019-04-29 21:20:41    NaN       NaN  13.59
# 2019-04-29 22:08:22    NaN     25.75    NaN
# 2019-04-29 23:05:04    NaN       NaN  14.59
# 2019-04-29 23:10:18    NaN     29.39    NaN
#
# [2218 rows x 3 columns]>

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
trips_df = trips_2019.resample('W').sum()
trips_df.head(10)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

trips = trips_df.plot(figsize = (20,6))
trips.set_title("Total Fare by City Type")
trips.set_ylabel("Fare ($USD)")
trips.set_xlabel("")

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

plt.savefig("analysis/PyBer_fare_summary.png")

plt.show()
